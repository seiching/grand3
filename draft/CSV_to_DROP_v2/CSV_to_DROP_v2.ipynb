# %%
# DROP 架構
# {'nfl_': [{'passage', 'qa_pairs'}, {p,q_p}, ...]}
#                       'qa_pairs': [{'question','answer','query_id'}, {q,a,q_i}, ...]
#                                                'answer': [{'number','unit','yesno','spans'}, {n,u,y,s}, ...]


## 讀CSV檔
import pandas as pd

FilePath = 'resultA_edit.csv'

print(FilePath)
df = pd.read_csv(FilePath, encoding='utf-8',dtype=str)    # 資料型態為 DataFrame

isNan = df.isnull()    # 判斷空格值 Nan


## 每橫排取出對應資料，組合成 DROP 格式
NFL = []
NFL_nLIST = []
NFL_LIST = []

DATA = {}

ANSWER = []
QA_PAIRS = []

PID = 0    # 預設文本 P 之ID
QID = 0    # 預設問題 Q 之ID
P = df['passage'][0]

for i in range( len(df) ):

    if P == df['passage'][i] or isNan['passage'][i] == True:    # '文章'若相同 or 留空
        PASSAGE = P
        ANSWER = []

    elif P != df['passage'][i]:    # '文章'若不同

        NFL_n = 'nlf_' + str(PID).zfill(4)    # DROP之 'nfl_'  <設定編號>
        NFL_nLIST.extend([NFL_n])

        # 建立DROP之 'nfl_': [{'passage', 'qa_pairs'}, {p,q_p}, ...]
        NFL.extend([{ 'passage':PASSAGE, 'qa_pairs':QA_PAIRS }])
        NFL_LIST.extend(NFL)
        
        NFL = []
        PID = PID +1    # 累加文本 P 之ID

        ANSWER = []
        QA_PAIRS = []

        PASSAGE = df['passage'][i]
        P = PASSAGE


    # 每橫排取出對應資料
    PASSAGE = P
    QUESTION = df['question'][i]
    NUMBER = df['number'][i]
    UNIT = df['unit'][i]
    YESNO = df['yesno'][i]
    SPANS = df['spans'][i]
    QUERY_ID = df['query_id'][i]

    # 若為空格值 Nan，將對應資料改為預設值
    if isNan['number'][i] == True:
        NUMBER = []
    if isNan['unit'][i] == True:
        UNIT = []
    if isNan['yesno'][i] == True:
        YESNO = ''
    if isNan['spans'][i] == True:
        SPANS = []

        
    # 建立DROP之 'answer': [{'number','unit','yesno','spans'}]
    ANSWER.extend([{ 'number':NUMBER, 'unit':UNIT, 'yesno':YESNO, 'spans':SPANS }])

    # 建立DROP之 'qa_pairs': [{'question','answer','query_id'}, {q,a,q_i}, ...]
    QA_PAIRS.extend([{ 'question':QUESTION, 'answer':ANSWER ,'query_id':QUERY_ID }])

# 最後一個文本，建立DROP之 'nfl_': [{'passage', 'qa_pairs'}, {p,q_p}, ...]
NFL.extend([{ 'passage':PASSAGE, 'qa_pairs':QA_PAIRS }])
NFL_LIST.extend(NFL)

NFL_n = 'nlf_' + str(PID).zfill(4)    # DROP之 'nfl_'  <設定編號>
NFL_nLIST.extend([NFL_n])

DATA = dict(zip( NFL_nLIST,NFL_LIST ))


## 存檔
import json

jsdumps = json.dumps(DATA, ensure_ascii=False)
fileName = 'CSV_DROP_v1.json'
outfile = open(fileName, 'w', encoding='utf-8')
outfile.write(jsdumps)
outfile.close()
# Out:
# resultA_edit.csv

# %%
DATA
# Out:
# {'nlf_0000': {'passage': '\n（中央社記者吳柏緯台北11日電）民間發展太空火箭的晉陞太空科技公司，在台東縣達仁鄉南田村興建發射基地，原訂去年年底發射實驗火箭，但因未充分和當地居民溝通，引發爭議，晉陞公司也決定暫緩發射。經過與當地居民，以及政府相關部會協調、研商後，確認13日清晨將試射自製火箭「飛鼠一號」',
#   'qa_pairs': [{'question': '請問文章中提到晉陞公司和誰協調研商後，確認13日清晨將試射自製火箭「飛鼠一號」?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[當地居民，以及政府相關部會]'}],
#     'query_id': 1000}]},
#  'nlf_0001': {'passage': '（中央社記者劉世怡台北12日電）前法務部長邱太三遭指為壢新醫院院長張煥禎逃漏稅案，關說前桃園地檢署檢察長彭坤業，監察院昨天未通過彈劾。邱太三今天聲明，他是轉知陳情、絕無關說，監察院已還他清白。\n此案去年經媒體披露後，監察委員林雅鋒、王美玉、高涌誠申請自動調查；去年召開第一次彈劾會，昨天召開第二次，皆未通過彈劾邱太三。\n邱太三今天發布聲明表示，經過兩次調查報告審查會，肯定多數監察委員對事實的爬梳，非由少數監委自由心證指摘認定。\n聲明指出，整件事從頭到尾只有陳述性質，完全沒有介入個案請求，更沒有違背法令。從頭到尾，他都沒有對彭坤業提出任何影響辦案方向的請求，甚至也沒有詢問追蹤後續處理情形，這些事實都可從相關人的證詞中得知。\n聲明表示，陳述此事在意的是司法形象與威信是否能獲得人民信賴，以及司法機關在司法訴訟制定是否造成人民疑慮無所適從，機制上是否有精進之處。\n聲明提及，三名監委所提調查報告的彈劾案，歷經兩次監院審查會，分別以懸殊票數，通過不彈劾，證明多數監委都認同他從頭到尾都是轉知陳情民怨、絕無關說。\n聲明指出，監察院已還他清白，至於少數監委的個人心證推論報告，投票結果已經證明沒有說服力，也不值一駁',
#   'qa_pairs': [{'question': '文章中提到前法務部長邱太三遭指為壢新醫院院長張煥禎逃漏稅案由那幾位監委申請自動調查?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[林雅鋒、王美玉及高涌誠]'}],
#     'query_id': 1001},
#    {'question': '文章中提到那些現任及前任公務員?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': ' [邱太三、彭坤業、林雅鋒、王美玉及高涌誠]'}],
#     'query_id': 1002},
#    {'question': '文章中提到那些政府機關?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[法務部、桃園地檢署及監察院]'}],
#     'query_id': 1003}]},
#  'nlf_0002': {'passage': '（中央社記者林育立柏林11日專電）駐德代表謝志偉日前將台灣數位修復的柏林老照片和法藍瓷專書送給柏林國立圖書館典藏，由普魯士文化遺產基金會主席帕辛格（Hermann Parzinger）代表接受。\n致贈儀式10日下午在柏林國立圖書館（Staatsbibliothek zu Berlin）舉行，館長施奈德-坎普夫 （Barbara Schneider-Kempf）也到場觀禮。這座17世紀成立的圖書館隸屬普魯士文化遺產基金會，館藏圖書超過1100萬冊，從規模來看是德語國家最大的圖書館。\n謝志偉致詞時表示，這張涵蓋皇宮、大教堂和博物館島的全景圖，原本是張充滿黃斑的老照片，新世語文化公司創辦人徐宗懋向德國舊書商買下後，用數位技術複製、掃描處理和復原上色，成功重現一百年前的城市榮光，展現台灣數位影像處理的頂級技術。\n',
#   'qa_pairs': [{'question': '文章中提到的老照片涵蓋那些地方?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[皇宮、大教堂和博物館島]'}],
#     'query_id': 1004}]},
#  'nlf_0003': {'passage': '（中央社記者戴雅真倫敦9日專電）國民黨立法委員許毓仁近期訪英，5日舉辦座談會和旅英科技業人士商討他正在推動的人工智慧發展基本法，盼奠定「人工智慧的憲法」，對人工智慧進行倫理規範。\n\n「AI法理情」座談會邀請台灣人工智慧安全控制新創Umbo CV技術長張秉霖 、Hyper Reality Ltd創辦人陳裕仁，以及工業設計師林珈弘等人與談，與許毓仁意見交流。\n\n許毓仁與跨黨派立委合作提案的「人工智慧發展基本法」在上會期通過一讀，分為醫療、智慧製造和無人車，台灣人工智慧應用三大最有潛力的領域，盼這會期完成三讀。\n\n許毓仁在座談會上指出，美國和中國的貿易戰將會持續5至10年，繼課稅之後，美中貿易戰的下一階段就是科技、智慧財產權等。在美中對戰當中，台灣應該做的是把核心關鍵技術留在台灣，並和美國形成戰略聯盟，因此推動通過人工智慧發展基本法有其必要。\n\n此外，他表示，台灣的公部門每個月面對駭客攻擊3000萬次，桃園機場附近的智慧路燈也曾被駭客攻擊，台灣基本上是處於資訊戰爭的狀態，為了國安、工業資安、科技發展與技術開發，應對人工智慧給予最高國家戰略思考。\n\n許毓仁表示，他推動的人工智慧發展基本法有5大準則。第一，確定人工智慧發展的定位，訂立發展綱領在產業界和學術界優先推動研究、發展。第二，促進產業AI化、建立AI技術應用平台，以及形成AI產業生態系。第三，AI發展牽涉大規模公眾數據的使用以及實驗場域落地試驗，與公共利益牽連甚深，須制定適當的開發標準原則。\n\n第四，政府在符合開發標準原則下，應盡量滿足產業、學術界在AI研發與應用的需求。第五，建立與凝聚公眾對AI的認識與信任，樹立人工智慧發展的基本倫理原則。\n\n許毓仁指出，歐盟在今年4月發布7條人工智慧的道德準則，包括AI不應侵犯人類自主性與自由、搜集的數據得受到安全且隱密的管理，以及需建立咎責機制等，英國也有人工智慧的開發準則，台灣應該儘速通過相當於AI憲法的人工智慧發展基本法，解開人工智慧發展的最後一道枷鎖。',
#   'qa_pairs': [{'question': '文章中提到那些人?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[許毓仁、張秉霖、陳裕仁及林珈弘]'}],
#     'query_id': 1005},
#    {'question': '文中提到「人工智慧發展基本法」在上會期通過一讀包含那三個領域?',
#     'answer': [{'number': [],
#       'unit': [],
#       'yesno': '',
#       'spans': '[醫療、智慧製造和無人車]'}],
#     'query_id': 1006}]}}
